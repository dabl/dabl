# %%
import fml

# %%
import pandas as pd

# %%
avocado = pd.read_csv("/home/andy/datasets/avocado.csv", parse_dates=['Date'])
telco_churn = pd.read_csv("/home/andy/datasets/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
from fml.preprocessing import FriendlyPreprocessor

# %%
sp = FriendlyPreprocessor(verbose=10)
sp.fit(avocado)
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64
# Detected feature types:
# 9 float, 2 int, 2 object, 1 date, 0 other
# Interpreted as:
# 11 continuous, 4 categorical, 1 date, 0 dirty float, 0 dropped
# FriendlyPreprocessor(scale=True, types=None, verbose=10)

# %%
y = telco_churn.Churn
X = telco_churn.drop("Churn", axis=1)

# %%
y.value_counts() / y.size
# Out:
# No     0.73463
# Yes    0.26537
# Name: Churn, dtype: float64

# %%
from fml.models import FriendlyClassifier

# %%
# %%prun -s cumulative -l 100
fc = FriendlyClassifier().fit(X, y)
# Out:
# DummyClassifier(constant=None, random_state=None, strategy='prior')
# fit_time         0.005028
# score_time       0.002350
# test_accuracy    0.734630
# dtype: float64
# GaussianNB(priors=None, var_smoothing=1e-09)
# fit_time         0.256916
# score_time       0.029334
# test_accuracy    0.661221
# dtype: float64
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# fit_time         0.264871
# score_time       0.028994
# test_accuracy    0.731080
# dtype: float64
# DecisionTreeClassifier(class_weight='balanced', criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# fit_time         0.237195
# score_time       0.028135
# test_accuracy    0.654410
# dtype: float64
# DecisionTreeClassifier(class_weight='balanced', criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# fit_time         0.258027
# score_time       0.028517
# test_accuracy    0.724405
# dtype: float64
#          7057452 function calls (7017790 primitive calls) in 5.870 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1335 to 100 due to restriction <100>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    5.870    5.870 {built-in method builtins.exec}
#         1    0.000    0.000    5.870    5.870 <string>:2(<module>)
#         1    0.000    0.000    5.870    5.870 models.py:25(fit)
#         5    0.000    0.000    5.819    1.164 models.py:67(_evaluate_one)
#         5    0.000    0.000    5.810    1.162 _validation.py:40(cross_validate)
#     125/5    0.010    0.000    5.790    1.158 parallel.py:932(__call__)
#    450/30    0.003    0.000    5.788    0.193 parallel.py:801(dispatch_one_batch)
#    325/25    0.003    0.000    5.705    0.228 parallel.py:764(_dispatch)
#    325/25    0.001    0.000    5.705    0.228 _parallel_backends.py:180(apply_async)
#    325/25    0.001    0.000    5.704    0.228 _parallel_backends.py:542(__init__)
#    325/25    0.002    0.000    5.704    0.228 parallel.py:258(__call__)
#    325/25    0.007    0.000    5.704    0.228 parallel.py:260(<listcomp>)
#        25    0.000    0.000    5.697    0.228 _validation.py:390(_fit_and_score)
#        20    0.000    0.000    5.037    0.252 pipeline.py:239(fit)
#     80/20    0.001    0.000    4.647    0.232 pipeline.py:190(_fit)
#     95/25    0.000    0.000    4.643    0.186 memory.py:328(__call__)
#    195/25    0.001    0.000    4.643    0.186 pipeline.py:612(_fit_transform_one)
#    155/25    0.001    0.000    4.643    0.186 base.py:438(fit_transform)
#        20    0.001    0.000    3.659    0.183 preprocessing.py:239(fit)
#    120/60    0.001    0.000    2.738    0.046 _column_transformer.py:380(_fit_transform)
#        20    0.010    0.001    2.204    0.110 preprocessing.py:48(detect_types_dataframe)
#        40    0.000    0.000    1.947    0.049 frame.py:5837(apply)
#        40    0.000    0.000    1.946    0.049 apply.py:311(get_result)
#        40    0.001    0.000    1.946    0.049 apply.py:105(get_result)
#        40    0.001    0.000    1.945    0.049 apply.py:219(apply_standard)
#       420    0.001    0.000    1.847    0.004 strings.py:2420(match)
#        40    0.007    0.000    1.832    0.046 {pandas._libs.reduction.reduce}
#       420    0.001    0.000    1.810    0.004 strings.py:708(str_match)
#       440    0.001    0.000    1.809    0.004 strings.py:148(_na_map)
#       440    0.003    0.000    1.808    0.004 strings.py:153(_map)
#       440    0.450    0.001    1.706    0.004 {pandas._libs.lib.map_infer_mask}
#       340    0.002    0.000    1.606    0.005 preprocessing.py:106(<lambda>)
#        40    0.000    0.000    1.466    0.037 preprocessing.py:309(transform)
#     80/40    0.001    0.000    1.466    0.037 _column_transformer.py:473(transform)
#        20    0.000    0.000    1.434    0.072 _column_transformer.py:400(fit)
#     40/20    0.001    0.000    1.434    0.072 _column_transformer.py:423(fit_transform)
#   2281932    0.501    0.000    1.256    0.000 strings.py:752(<lambda>)
#   200/120    0.000    0.000    1.198    0.010 pipeline.py:604(_transform_one)
#       116    0.006    0.000    0.917    0.008 _encoders.py:581(transform)
#        60    0.004    0.000    0.911    0.015 preprocessing.py:29(transform)
#       116    0.024    0.000    0.911    0.008 _encoders.py:551(_transform_new)
#   2281932    0.755    0.000    0.755    0.000 {method 'match' of 're.Pattern' objects}
#    120/80    0.001    0.000    0.709    0.009 pipeline.py:447(_transform)
#     60/40    0.000    0.000    0.703    0.018 pipeline.py:270(fit_transform)
#       116    0.011    0.000    0.637    0.005 _encoders.py:93(_transform)
#        25    0.000    0.000    0.587    0.023 _validation.py:582(_score)
#        25    0.000    0.000    0.586    0.023 _validation.py:611(_multimetric_score)
#        25    0.000    0.000    0.586    0.023 scorer.py:67(__call__)
#       728    0.003    0.000    0.557    0.001 indexing.py:1463(__getitem__)
#        20    0.000    0.000    0.534    0.027 metaestimators.py:118(<lambda>)
#        20    0.000    0.000    0.533    0.027 pipeline.py:306(predict)
# 25038/24371    0.304    0.000    0.520    0.000 {built-in method numpy.core.multiarray.array}
#      1376    0.015    0.000    0.507    0.000 label.py:77(_encode)
#        20    0.000    0.000    0.502    0.025 _encoders.py:478(fit_transform)
#      1376    0.045    0.000    0.491    0.000 label.py:60(_encode_python)
#       450    0.002    0.000    0.479    0.001 parallel.py:252(__init__)
#       572    0.012    0.000    0.428    0.001 validation.py:357(check_array)
#       336    0.003    0.000    0.424    0.001 indexing.py:868(_getitem_tuple)
#       412    0.002    0.000    0.397    0.001 indexing.py:1854(_getitem_axis)
#       420    0.002    0.000    0.394    0.001 _column_transformer.py:390(<genexpr>)
#       121    0.000    0.000    0.311    0.003 base.py:52(__str__)
#       121    0.002    0.000    0.310    0.003 series.py:1221(__unicode__)
#       300    0.002    0.000    0.308    0.001 _column_transformer.py:569(_get_column)
#       121    0.001    0.000    0.301    0.002 series.py:1240(to_string)
#       621    0.001    0.000    0.294    0.000 generic.py:4563(values)
#       621    0.002    0.000    0.288    0.000 internals.py:3922(as_array)
#       336    0.001    0.000    0.286    0.001 indexing.py:1489(_getbool_axis)
#       260    0.136    0.001    0.282    0.001 internals.py:3953(_interleave)
#       277    0.002    0.000    0.273    0.001 arraysetops.py:113(unique)
#       277    0.017    0.000    0.269    0.001 arraysetops.py:256(_unique1d)
#        10    0.000    0.000    0.252    0.025 tree.py:759(fit)
#        10    0.001    0.000    0.252    0.025 tree.py:111(fit)
#       446    0.004    0.000    0.244    0.001 generic.py:2783(_take)
#     11354    0.005    0.000    0.242    0.000 numeric.py:424(asarray)
#       762    0.004    0.000    0.240    0.000 internals.py:4388(reindex_indexer)
#      7009    0.006    0.000    0.232    0.000 {pandas._libs.lib.values_from_object}
#      4330    0.029    0.000    0.227    0.000 series.py:166(__init__)
#       556    0.001    0.000    0.220    0.000 generic.py:1605(__array__)
#       556    0.001    0.000    0.218    0.000 generic.py:4645(get_values)
#       446    0.005    0.000    0.215    0.000 internals.py:4518(take)
#       400    0.001    0.000    0.207    0.001 preprocessing.py:91(<lambda>)
#       400    0.001    0.000    0.206    0.001 base.py:1053(nunique)
#        60    0.000    0.000    0.205    0.003 series.py:882(__setitem__)
#        60    0.001    0.000    0.205    0.003 series.py:885(setitem)
#      1036    0.203    0.000    0.203    0.000 label.py:68(<listcomp>)
#        56    0.001    0.000    0.201    0.004 indexing.py:182(__setitem__)
#      9800    0.004    0.000    0.200    0.000 missing.py:32(isna)
#       282    0.198    0.001    0.198    0.001 {method 'sort' of 'numpy.ndarray' objects}
#      9800    0.010    0.000    0.196    0.000 missing.py:112(_isna_new)
#       121    0.002    0.000    0.190    0.002 format.py:262(to_string)
#      2622    0.028    0.000    0.180    0.000 algorithms.py:1548(take_nd)
#       400    0.001    0.000    0.178    0.000 series.py:1448(unique)
#        20    0.001    0.000    0.177    0.009 preprocessing.py:16(fit)
#       400    0.001    0.000    0.175    0.000 base.py:1041(unique)
#      2229    0.033    0.000    0.173    0.000 missing.py:189(_isna_ndarraylike)
#       400    0.003    0.000    0.172    0.000 algorithms.py:283(unique)
#        60    0.000    0.000    0.166    0.003 series.py:943(_set_with_engine)
#        60    0.001    0.000    0.165    0.003 {method 'set_value' of 'pandas._libs.index.IndexEngine' objects}
#       636    0.007    0.000    0.160    0.000 internals.py:4431(_slice_take_blocks_ax0)
#        10    0.157    0.016    0.157    0.016 {method 'build' of 'sklearn.tree._tree.DepthFirstTreeBuilder' objects}

# %%
from sklearn.externals import joblib

# %%
# %%prun -s cumulative -l 100
fc = FriendlyClassifier(joblib.Memory(local='/dev/shm/')).fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f72f083f2fd9> in <module>()
# ----> 1 get_ipython().run_cell_magic('prun', '-s cumulative -l 100', "fc = FriendlyClassifier(joblib.Memory(cache_dir='/dev/shm/')).fit(X, y)")
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2165             magic_arg_s = self.var_expand(line, stack_depth)
#    2166             with self.builtin_trap:
# -> 2167                 result = fn(magic_arg_s, cell)
#    2168             return result
#    2169
#
# <decorator-gen-56> in prun(self, parameter_s, cell)
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/IPython/core/magics/execution.py in prun(self, parameter_s, cell)
#     300             arg_str += '\n' + cell
#     301         arg_str = self.shell.input_splitter.transform_cell(arg_str)
# --> 302         return self._run_with_profiler(arg_str, opts, self.shell.user_ns)
#     303
#     304     def _run_with_profiler(self, code, opts, namespace):
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/IPython/core/magics/execution.py in _run_with_profiler(self, code, opts, namespace)
#     322         prof = profile.Profile()
#     323         try:
# --> 324             prof = prof.runctx(code, namespace, namespace)
#     325             sys_exit = ''
#     326         except SystemExit:
#
# ~/anaconda3/envs/py37/lib/python3.7/cProfile.py in runctx(self, cmd, globals, locals)
#      98         self.enable()
#      99         try:
# --> 100             exec(cmd, globals, locals)
#     101         finally:
#     102             self.disable()
#
# <string> in <module>()
#
# TypeError: __init__() got an unexpected keyword argument 'cache_dir'

# %%
from fml.preprocessing import safe_cleanup

# %%
X_cleanish = safe_cleanup(X, onehot=True)

X_cleanish.columns
# Out:
# Index(['x0_ ', 'TotalCharges_fml_continuous', 'SeniorCitizen', 'tenure',
#        'MonthlyCharges', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'Dependents_No', 'Dependents_Yes',
#        ...
#        'tenure_63', 'tenure_64', 'tenure_65', 'tenure_66', 'tenure_67',
#        'tenure_68', 'tenure_69', 'tenure_70', 'tenure_71', 'tenure_72'],
#       dtype='object', length=119)

# %%
X_cleanish.shape
# Out:
# (7043, 119)

# %%
from fml.preprocessing import detect_types_dataframe

# %%
detect_types_dataframe(X_cleanish, verbose=10)
# Out:
# x0_                                           2
# TotalCharges_fml_continuous                6530
# SeniorCitizen                                 2
# tenure                                       73
# MonthlyCharges                             1585
# Contract_Month-to-month                       2
# Contract_One year                             2
# Contract_Two year                             2
# Dependents_No                                 2
# Dependents_Yes                                2
# DeviceProtection_No                           2
# DeviceProtection_No internet service          2
# DeviceProtection_Yes                          2
# InternetService_DSL                           2
# InternetService_Fiber optic                   2
# InternetService_No                            2
# MultipleLines_No                              2
# MultipleLines_No phone service                2
# MultipleLines_Yes                             2
# OnlineBackup_No                               2
# OnlineBackup_No internet service              2
# OnlineBackup_Yes                              2
# OnlineSecurity_No                             2
# OnlineSecurity_No internet service            2
# OnlineSecurity_Yes                            2
# PaperlessBilling_No                           2
# PaperlessBilling_Yes                          2
# Partner_No                                    2
# Partner_Yes                                   2
# PaymentMethod_Bank transfer (automatic)       2
#                                            ...
# tenure_43                                     2
# tenure_44                                     2
# tenure_45                                     2
# tenure_46                                     2
# tenure_47                                     2
# tenure_48                                     2
# tenure_49                                     2
# tenure_50                                     2
# tenure_51                                     2
# tenure_52                                     2
# tenure_53                                     2
# tenure_54                                     2
# tenure_55                                     2
# tenure_56                                     2
# tenure_57                                     2
# tenure_58                                     2
# tenure_59                                     2
# tenure_60                                     2
# tenure_61                                     2
# tenure_62                                     2
# tenure_63                                     2
# tenure_64                                     2
# tenure_65                                     2
# tenure_66                                     2
# tenure_67                                     2
# tenure_68                                     2
# tenure_69                                     2
# tenure_70                                     2
# tenure_71                                     2
# tenure_72                                     2
# Length: 119, dtype: int64
# Detected feature types:
# 3 float, 116 int, 0 object, 0 date, 0 other
# Interpreted as:
# 119 continuous, 1 categorical, 0 date, 0 dirty float, 0 dropped
#                                          continuous  categorical   date  \
# x0_                                            True        False  False
# TotalCharges_fml_continuous                    True        False  False
# SeniorCitizen                                  True        False  False
# tenure                                         True         True  False
# MonthlyCharges                                 True        False  False
# Contract_Month-to-month                        True        False  False
# Contract_One year                              True        False  False
# Contract_Two year                              True        False  False
# Dependents_No                                  True        False  False
# Dependents_Yes                                 True        False  False
# DeviceProtection_No                            True        False  False
# DeviceProtection_No internet service           True        False  False
# DeviceProtection_Yes                           True        False  False
# InternetService_DSL                            True        False  False
# InternetService_Fiber optic                    True        False  False
# InternetService_No                             True        False  False
# MultipleLines_No                               True        False  False
# MultipleLines_No phone service                 True        False  False
# MultipleLines_Yes                              True        False  False
# OnlineBackup_No                                True        False  False
# OnlineBackup_No internet service               True        False  False
# OnlineBackup_Yes                               True        False  False
# OnlineSecurity_No                              True        False  False
# OnlineSecurity_No internet service             True        False  False
# OnlineSecurity_Yes                             True        False  False
# PaperlessBilling_No                            True        False  False
# PaperlessBilling_Yes                           True        False  False
# Partner_No                                     True        False  False
# Partner_Yes                                    True        False  False
# PaymentMethod_Bank transfer (automatic)        True        False  False
# ...                                             ...          ...    ...
# tenure_43                                      True        False  False
# tenure_44                                      True        False  False
# tenure_45                                      True        False  False
# tenure_46                                      True        False  False
# tenure_47                                      True        False  False
# tenure_48                                      True        False  False
# tenure_49                                      True        False  False
# tenure_50                                      True        False  False
# tenure_51                                      True        False  False
# tenure_52                                      True        False  False
# tenure_53                                      True        False  False
# tenure_54                                      True        False  False
# tenure_55                                      True        False  False
# tenure_56                                      True        False  False
# tenure_57                                      True        False  False
# tenure_58                                      True        False  False
# tenure_59                                      True        False  False
# tenure_60                                      True        False  False
# tenure_61                                      True        False  False
# tenure_62                                      True        False  False
# tenure_63                                      True        False  False
# tenure_64                                      True        False  False
# tenure_65                                      True        False  False
# tenure_66                                      True        False  False
# tenure_67                                      True        False  False
# tenure_68                                      True        False  False
# tenure_69                                      True        False  False
# tenure_70                                      True        False  False
# tenure_71                                      True        False  False
# tenure_72                                      True        False  False
#
#                                          dirty_float  useless
# x0_                                            False    False
# TotalCharges_fml_continuous                    False    False
# SeniorCitizen                                  False    False
# tenure                                         False    False
# MonthlyCharges                                 False    False
# Contract_Month-to-month                        False    False
# Contract_One year                              False    False
# Contract_Two year                              False    False
# Dependents_No                                  False    False
# Dependents_Yes                                 False    False
# DeviceProtection_No                            False    False
# DeviceProtection_No internet service           False    False
# DeviceProtection_Yes                           False    False
# InternetService_DSL                            False    False
# InternetService_Fiber optic                    False    False
# InternetService_No                             False    False
# MultipleLines_No                               False    False
# MultipleLines_No phone service                 False    False
# MultipleLines_Yes                              False    False
# OnlineBackup_No                                False    False
# OnlineBackup_No internet service               False    False
# OnlineBackup_Yes                               False    False
# OnlineSecurity_No                              False    False
# OnlineSecurity_No internet service             False    False
# OnlineSecurity_Yes                             False    False
# PaperlessBilling_No                            False    False
# PaperlessBilling_Yes                           False    False
# Partner_No                                     False    False
# Partner_Yes                                    False    False
# PaymentMethod_Bank transfer (automatic)        False    False
# ...                                              ...      ...
# tenure_43                                      False    False
# tenure_44                                      False    False
# tenure_45                                      False    False
# tenure_46                                      False    False
# tenure_47                                      False    False
# tenure_48                                      False    False
# tenure_49                                      False    False
# tenure_50                                      False    False
# tenure_51                                      False    False
# tenure_52                                      False    False
# tenure_53                                      False    False
# tenure_54                                      False    False
# tenure_55                                      False    False
# tenure_56                                      False    False
# tenure_57                                      False    False
# tenure_58                                      False    False
# tenure_59                                      False    False
# tenure_60                                      False    False
# tenure_61                                      False    False
# tenure_62                                      False    False
# tenure_63                                      False    False
# tenure_64                                      False    False
# tenure_65                                      False    False
# tenure_66                                      False    False
# tenure_67                                      False    False
# tenure_68                                      False    False
# tenure_69                                      False    False
# tenure_70                                      False    False
# tenure_71                                      False    False
# tenure_72                                      False    False
#
# [119 rows x 5 columns]

# %%
X_cleanish.shape
# Out:
# (7043, 119)

# %%
fp = FriendlyPreprocessor()
fp.fit_transform(X_cleanish).shape
# Out:
# (7043, 192)

# %%
# %%prun -s cumulative -l 100 -D test.prof
X_cleanish = safe_cleanup(X, onehot=True)
fc = FriendlyClassifier().fit(X_cleanish, y)
# Out:
# DummyClassifier(constant=None, random_state=None, strategy='prior')
# fit_time                   0.004455
# score_time                 0.010412
# test_accuracy              0.734630
# train_accuracy             0.734630
# test_average_precision     0.265370
# train_average_precision    0.265370
# test_roc_auc               0.500000
# train_roc_auc              0.500000
# test_precision_macro       0.367315
# train_precision_macro      0.367315
# dtype: float64
# GaussianNB(priors=None, var_smoothing=1e-09)
# fit_time                   0.098654
# score_time                 0.050067
# test_accuracy              0.596049
# train_accuracy             0.610500
# test_average_precision     0.420463
# train_average_precision    0.439988
# test_roc_auc               0.724284
# train_roc_auc              0.747796
# test_precision_macro       0.642855
# train_precision_macro      0.656280
# dtype: float64
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# fit_time                   0.100408
# score_time                 0.044273
# test_accuracy              0.739316
# train_accuracy             0.742865
# test_average_precision     0.631536
# train_average_precision    0.639603
# test_roc_auc               0.825740
# train_roc_auc              0.831570
# test_precision_macro       0.705550
# train_precision_macro      0.709238
# dtype: float64
# DecisionTreeClassifier(class_weight='balanced', criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# fit_time                   0.086498
# score_time                 0.041465
# test_accuracy              0.654410
# train_accuracy             0.654409
# test_average_precision     0.408651
# train_average_precision    0.408584
# test_roc_auc               0.728213
# train_roc_auc              0.728216
# test_precision_macro       0.679810
# train_precision_macro      0.679775
# dtype: float64
# DecisionTreeClassifier(class_weight='balanced', criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# fit_time                   0.109735
# score_time                 0.040002
# test_accuracy              0.724546
# train_accuracy             0.747764
# test_average_precision     0.605022
# train_average_precision    0.642543
# test_roc_auc               0.827966
# train_roc_auc              0.852527
# test_precision_macro       0.698869
# train_precision_macro      0.720309
# dtype: float64
#
# *** Profile stats marshalled to file 'test.prof'.
#          1538259 function calls (1514676 primitive calls) in 6.158 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1420 to 100 due to restriction <100>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    6.158    6.158 {built-in method builtins.exec}
#         1    0.000    0.000    6.157    6.157 <string>:2(<module>)
#         1    0.000    0.000    5.885    5.885 models.py:25(fit)
#         5    0.000    0.000    5.845    1.169 models.py:65(_evaluate_one)
#         5    0.000    0.000    5.835    1.167 _validation.py:40(cross_validate)
#     205/5    0.009    0.000    5.821    1.164 parallel.py:932(__call__)
#    630/30    0.005    0.000    5.820    0.194 parallel.py:801(dispatch_one_batch)
#    425/25    0.004    0.000    5.757    0.230 parallel.py:764(_dispatch)
#    425/25    0.001    0.000    5.757    0.230 _parallel_backends.py:180(apply_async)
#    425/25    0.001    0.000    5.757    0.230 _parallel_backends.py:542(__init__)
#    425/25    0.003    0.000    5.757    0.230 parallel.py:258(__call__)
#    425/25    0.002    0.000    5.756    0.230 parallel.py:260(<listcomp>)
#        25    0.001    0.000    5.755    0.230 _validation.py:390(_fit_and_score)
#        50    0.000    0.000    3.756    0.075 _validation.py:582(_score)
#        50    0.002    0.000    3.756    0.075 _validation.py:611(_multimetric_score)
#       200    0.002    0.000    2.700    0.014 _column_transformer.py:380(_fit_transform)
#       160    0.001    0.000    2.306    0.014 metaestimators.py:118(<lambda>)
#       180    0.002    0.000    2.039    0.011 preprocessing.py:309(transform)
#       180    0.002    0.000    2.036    0.011 _column_transformer.py:473(transform)
#        20    0.000    0.000    1.915    0.096 pipeline.py:239(fit)
#       100    0.002    0.000    1.893    0.019 scorer.py:142(__call__)
#       100    0.001    0.000    1.860    0.019 scorer.py:67(__call__)
#     71/26    0.001    0.000    1.461    0.056 base.py:438(fit_transform)
#     40/20    0.001    0.000    1.439    0.072 pipeline.py:190(_fit)
#      2152    0.012    0.000    1.439    0.001 arraysetops.py:113(unique)
#     50/25    0.000    0.000    1.436    0.057 memory.py:328(__call__)
#     90/25    0.000    0.000    1.436    0.057 pipeline.py:612(_fit_transform_one)
#      2152    0.077    0.000    1.422    0.001 arraysetops.py:256(_unique1d)
#       360    0.001    0.000    1.239    0.003 pipeline.py:604(_transform_one)
#      2188    1.237    0.001    1.237    0.001 {method 'sort' of 'numpy.ndarray' objects}
#        80    0.001    0.000    1.183    0.015 pipeline.py:364(predict_proba)
#        80    0.001    0.000    1.123    0.014 pipeline.py:306(predict)
#        20    0.001    0.000    1.112    0.056 preprocessing.py:239(fit)
#        20    0.000    0.000    1.091    0.055 _column_transformer.py:400(fit)
#        20    0.000    0.000    1.091    0.055 _column_transformer.py:423(fit_transform)
#       200    0.006    0.000    1.004    0.005 impute.py:353(transform)
#       180    0.002    0.000    0.958    0.005 pipeline.py:447(_transform)
#      1004    0.022    0.000    0.950    0.001 validation.py:357(check_array)
#        20    0.000    0.000    0.905    0.045 pipeline.py:270(fit_transform)
#       796    0.011    0.000    0.814    0.001 multiclass.py:174(type_of_target)
#        20    0.000    0.000    0.706    0.035 impute.py:210(fit)
#        20    0.000    0.000    0.639    0.032 impute.py:301(_dense_fit)
#        20    0.000    0.000    0.628    0.031 extras.py:617(median)
#        20    0.000    0.000    0.628    0.031 function_base.py:3982(_ureduce)
#        20    0.002    0.000    0.627    0.031 extras.py:699(_median)
#       220    0.002    0.000    0.589    0.003 impute.py:171(_validate_input)
#        20    0.000    0.000    0.584    0.029 core.py:6685(sort)
#        20    0.001    0.000    0.560    0.028 core.py:5484(sort)
#       630    0.003    0.000    0.517    0.001 parallel.py:252(__init__)
#       100    0.001    0.000    0.484    0.005 classification.py:44(_check_targets)
#        50    0.000    0.000    0.479    0.010 classification.py:1173(precision_score)
#        50    0.004    0.000    0.479    0.010 classification.py:882(precision_recall_fscore_support)
#       600    0.002    0.000    0.453    0.001 _column_transformer.py:390(<genexpr>)
#      7796    0.451    0.000    0.451    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       510    0.003    0.000    0.427    0.001 indexing.py:1463(__getitem__)
# 29606/27648    0.209    0.000    0.387    0.000 {built-in method numpy.core.multiarray.array}
#      1602    0.001    0.000    0.368    0.000 _methods.py:31(_sum)
#       200    0.001    0.000    0.362    0.002 _column_transformer.py:502(_hstack)
#       400    0.003    0.000    0.359    0.001 _column_transformer.py:569(_get_column)
#      3719    0.357    0.000    0.357    0.000 {built-in method numpy.core.multiarray.concatenate}
#       406    0.004    0.000    0.343    0.001 indexing.py:868(_getitem_tuple)
#       673    0.002    0.000    0.336    0.000 generic.py:4563(values)
#       457    0.005    0.000    0.335    0.001 generic.py:2783(_take)
#       255    0.001    0.000    0.330    0.001 shape_base.py:236(hstack)
#       673    0.003    0.000    0.328    0.000 internals.py:3922(as_array)
#       442    0.245    0.001    0.321    0.001 internals.py:3953(_interleave)
#        10    0.000    0.000    0.316    0.032 tree.py:759(fit)
#       578    0.316    0.001    0.316    0.001 {method 'argsort' of 'numpy.ndarray' objects}
#        10    0.001    0.000    0.316    0.032 tree.py:111(fit)
#       201    0.001    0.000    0.313    0.002 _encoders.py:581(transform)
#       201    0.009    0.000    0.312    0.002 _encoders.py:551(_transform_new)
#       408    0.002    0.000    0.309    0.001 indexing.py:1854(_getitem_axis)
#        20    0.000    0.000    0.303    0.015 core.py:5326(argsort)
#      2590    0.004    0.000    0.300    0.000 {pandas._libs.lib.values_from_object}
#       457    0.006    0.000    0.297    0.001 internals.py:4518(take)
#       663    0.001    0.000    0.296    0.000 generic.py:1605(__array__)
#       663    0.001    0.000    0.294    0.000 generic.py:4645(get_values)
#        50    0.000    0.000    0.293    0.006 ranking.py:130(average_precision_score)
#       406    0.002    0.000    0.291    0.001 indexing.py:1489(_getbool_axis)
#       330    0.286    0.001    0.286    0.001 {built-in method numpy.core.multiarray.where}
#        50    0.001    0.000    0.286    0.006 ranking.py:239(roc_auc_score)
#       100    0.002    0.000    0.284    0.003 arraysetops.py:590(union1d)
#       100    0.001    0.000    0.281    0.003 base.py:23(_average_binary_score)
#         1    0.000    0.000    0.273    0.273 preprocessing.py:163(safe_cleanup)
#      1218    0.087    0.000    0.269    0.000 validation.py:40(_assert_all_finite)
#        40    0.208    0.005    0.261    0.007 naive_bayes.py:429(_joint_log_likelihood)
#       465    0.003    0.000    0.254    0.001 internals.py:4388(reindex_indexer)
#        50    0.007    0.000    0.253    0.005 classification.py:115(accuracy_score)
#         2    0.001    0.001    0.249    0.125 preprocessing.py:48(detect_types_dataframe)
#     11827    0.005    0.000    0.246    0.000 numeric.py:424(asarray)
#         3    0.000    0.000    0.226    0.075 frame.py:5837(apply)
#         3    0.000    0.000    0.226    0.075 apply.py:311(get_result)
#         3    0.000    0.000    0.226    0.075 apply.py:105(get_result)
#         3    0.000    0.000    0.226    0.075 apply.py:219(apply_standard)
#        10    0.225    0.022    0.225    0.022 {method 'build' of 'sklearn.tree._tree.DepthFirstTreeBuilder' objects}
#        80    0.212    0.003    0.217    0.003 core.py:3186(__getitem__)
#      2712    0.027    0.000    0.205    0.000 algorithms.py:1548(take_nd)
#        60    0.002    0.000    0.199    0.003 multiclass.py:42(unique_labels)
#      1017    0.002    0.000    0.196    0.000 {method 'sum' of 'numpy.ndarray' objects}
#       100    0.010    0.000    0.191    0.002 ranking.py:354(_binary_clf_curve)
